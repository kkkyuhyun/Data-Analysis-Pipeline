# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

x = [1, 2, 3]
y = [2, 4, 8]

# %%
plt. plot(x,y,linewidth=5,marker='o')

# %%
plt.plot(x,y,linewidth=3,marker='o',markersize=10)

# %%
plt.plot(x, y, marker='o', markersize=10, color='blue')
plt.title('꺾은선 그래프', fontdict={'family': 'HYGungSo-Bold', 'size': 20})
plt.show()

# %% [markdown]
# 선 스타일

# %%
plt.plot(x,y,linestyle='--')

# %%
##색깔

# %%
plt.plot(x,y,color='pink')

# %%
plt.plot(x,y,color='#ff0000')

# %%
plt.plot(x,y,color='g')

# %%
#포맷

# %%
plt.plot(x,y,'ro--')
#처음에 있는 글자는 색깔, marker, linestyle

# %%
plt.plot(x,y,'bv:')

# %%
plt.plot(x,y,'g')

# %%
#축약어

# %%
plt.plot(x, y, marker='o', mfc='red', markersize=10, mec='blue', linestyle=':')
plt.title('꺾은선 그래프', fontdict={'family': 'HYGungSo-Bold', 'size': 20})
plt.show()

# %%
#투명도

# %%
plt.plot(x, y, marker='o', mfc='red', ms=10, alpha=0.4)
plt.title('꺾은선 그래프', fontdict={'family': 'HYGungSo-Bold', 'size': 20})
plt.show()

# %%
#그래프 크기

# %%
plt.figure(figsize=(10,5))#width:10 height: 5

plt. plot(x,y)

# %%
plt.figure(figsize=(10,5),dpi=50)
plt.plot(x,y)

# %%
#배경색

# %%
plt.figure(facecolor='yellow')
plt.plot(x,y)

# %%
plt.figure(facecolor='#a1c3ff')
plt.plot(x,y)
plt.show()
