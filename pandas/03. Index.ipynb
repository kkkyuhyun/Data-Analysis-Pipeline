# %% [markdown]
# 3. index 데이터에 접근할 수 있는 주소 값

# %%
lst=['유재석','하하']
lst[0]
# Out:
# '유재석'

# %%
import pandas as pd
data = {
    '이름': ['채치수', '정대만', '송태섭', '서태웅', '강백호', '황태산', '윤대형'],
    '학교': ['북산고'] * 5 + ['능남고'] * 3,
    '키': [197, 184, 168, 187, 188, 202, 188, 190],
    '국어': [90, 40, 80, 40, 15, 80, 55, 100],
    '영어': [85, 35, 75, 60, 20, 100, 65, 85],
    '수학': [100, 50, 70, 70, 10, 95, 45, 90],
    '과학': [95, 55, 80, 75, 35, 85, 40, 95],
    '사회': [85, 25, 75, 80, 10, 80, 35, 85],
    'SW특기': ['Python', 'Java', 'Javascript', '', 'C', 'Python', 'C#', '']
}
df = pd.DataFrame(data, index=['1번', '2번', '3번', '4번', '5번', '6번', '7번'])
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 13
#       1 import pandas as pd
#       2 data = {
#       3     '이름': ['채치수', '정대만', '송태섭', '서태웅', '강백호', '황태산', '윤대형'],
#       4     '학교': ['북산고'] * 5 + ['능남고'] * 3,
#    (...)
#      11     'SW특기': ['Python', 'Java', 'Javascript', '', 'C', 'Python', 'C#', '']
#      12 }
# ---> 13 df = pd.DataFrame(data, index=['1번', '2번', '3번', '4번', '5번', '6번', '7번'])
#      14 df
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:767, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     761     mgr = self._init_mgr(
#     762         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     763     )
#     765 elif isinstance(data, dict):
#     766     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 767     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     768 elif isinstance(data, ma.MaskedArray):
#     769     from numpy.ma import mrecords
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\construction.py:119, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     116         index = ensure_index(index)
#     118     # don't force copy because getting jammed in an ndarray anyway
# --> 119     arrays, refs = _homogenize(arrays, index, dtype)
#     120     # _homogenize ensures
#     121     #  - all(len(x) == len(index) for x in arrays)
#     122     #  - all(x.ndim == 1 for x in arrays)
#    (...)
#     125
#     126 else:
#     127     index = ensure_index(index)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\construction.py:630, in _homogenize(data, index, dtype)
#     627         val = lib.fast_multiget(val, oindex._values, default=np.nan)
#     629     val = sanitize_array(val, index, dtype=dtype, copy=False)
# --> 630     com.require_length_match(val, index)
#     631     refs.append(None)
#     633 homogenized.append(val)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\common.py:571, in require_length_match(data, index)
#     567 """
#     568 Check the length of data matches the length of the index.
#     569 """
#     570 if len(data) != len(index):
# --> 571     raise ValueError(
#     572         "Length of values "
#     573         f"({len(data)}) "
#     574         "does not match length of index "
#     575         f"({len(index)})"
#     576     )
#
# ValueError: Length of values (8) does not match length of index (7)

# %%
import pandas as pd
data = {
    '이름': ['채치수', '정대만', '송태섭', '서태웅', '강백호', '황태산', '윤대형'],
    '학교': ['북산고'] * 5 + ['능남고'] * 3,
    '키': [197, 184, 168, 187, 188, 202, 188, 190],
    '국어': [90, 40, 80, 40, 15, 80, 55, 100],
    '영어': [85, 35, 75, 60, 20, 100, 65, 85],
    '수학': [100, 50, 70, 70, 10, 95, 45, 90],
    '과학': [95, 55, 80, 75, 35, 85, 40, 95],
    '사회': [85, 25, 75, 80, 10, 80, 35, 85],
    'SW특기': ['Python', 'Java', 'Javascript', '', 'C', 'Python', 'C#', '']
}
df = pd.DataFrame(data, index=['1번', '2번', '3번', '4번', '5번', '6번', '7번'])
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 13
#       1 import pandas as pd
#       2 data = {
#       3     '이름': ['채치수', '정대만', '송태섭', '서태웅', '강백호', '황태산', '윤대형'],
#       4     '학교': ['북산고'] * 5 + ['능남고'] * 3,
#    (...)
#      11     'SW특기': ['Python', 'Java', 'Javascript', '', 'C', 'Python', 'C#', '']
#      12 }
# ---> 13 df = pd.DataFrame(data, index=['1번', '2번', '3번', '4번', '5번', '6번', '7번'])
#      14 df
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:767, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     761     mgr = self._init_mgr(
#     762         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     763     )
#     765 elif isinstance(data, dict):
#     766     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 767     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     768 elif isinstance(data, ma.MaskedArray):
#     769     from numpy.ma import mrecords
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\construction.py:119, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     116         index = ensure_index(index)
#     118     # don't force copy because getting jammed in an ndarray anyway
# --> 119     arrays, refs = _homogenize(arrays, index, dtype)
#     120     # _homogenize ensures
#     121     #  - all(len(x) == len(index) for x in arrays)
#     122     #  - all(x.ndim == 1 for x in arrays)
#    (...)
#     125
#     126 else:
#     127     index = ensure_index(index)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\construction.py:630, in _homogenize(data, index, dtype)
#     627         val = lib.fast_multiget(val, oindex._values, default=np.nan)
#     629     val = sanitize_array(val, index, dtype=dtype, copy=False)
# --> 630     com.require_length_match(val, index)
#     631     refs.append(None)
#     633 homogenized.append(val)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\common.py:571, in require_length_match(data, index)
#     567 """
#     568 Check the length of data matches the length of the index.
#     569 """
#     570 if len(data) != len(index):
# --> 571     raise ValueError(
#     572         "Length of values "
#     573         f"({len(data)}) "
#     574         "does not match length of index "
#     575         f"({len(index)})"
#     576     )
#
# ValueError: Length of values (8) does not match length of index (7)

# %%
import pandas as pd

# 주어진 데이터 딕셔너리
data = {
    '이름': ['채치수', '정대만', '송태섭', '서태웅', '강백호', '황태산', '윤대형'],
    '학교': ['북산고'] * 5 + ['능남고'] * 2,
    '키': [197, 184, 168, 187, 188, 202, 188],
    '국어': [90, 40, 80, 40, 15, 80, 55],
    '영어': [85, 35, 75, 60, 20, 100, 65],
    '수학': [100, 50, 70, 70, 10, 95, 45],
    '과학': [95, 55, 80, 75, 35, 85, 40],
    '사회': [85, 25, 75, 80, 10, 80, 35],
    'SW특기': ['Python', 'Java', 'Javascript', '', 'C', 'Python', 'C#']
}

# DataFrame 생성
df = pd.DataFrame(data)
df.index = ['1번', '2번', '3번', '4번', '5번', '6번', '7번']

# 생성된 DataFrame 출력
df
# Out:
#      이름   학교    키  국어   영어   수학  과학  사회        SW특기
# 1번  채치수  북산고  197  90   85  100  95  85      Python
# 2번  정대만  북산고  184  40   35   50  55  25        Java
# 3번  송태섭  북산고  168  80   75   70  80  75  Javascript
# 4번  서태웅  북산고  187  40   60   70  75  80
# 5번  강백호  북산고  188  15   20   10  35  10           C
# 6번  황태산  능남고  202  80  100   95  85  80      Python
# 7번  윤대형  능남고  188  55   65   45  40  35          C#

# %%
df.index
# Out:
# Index(['1번', '2번', '3번', '4번', '5번', '6번', '7번'], dtype='object')

# %% [markdown]
# Index 이름 설정

# %%
df.index.name='지원번호'
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.index.name='지원번호'
#       2 df
#
# NameError: name 'df' is not defined

# %%
df.index.name='지원번호'
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.index.name='지원번호'
#       2 df
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# 주어진 데이터 딕셔너리
data = {
    '이름': ['채치수', '정대만', '송태섭', '서태웅', '강백호', '황태산', '윤대형'],
    '학교': ['북산고'] * 5 + ['능남고'] * 2,
    '키': [197, 184, 168, 187, 188, 202, 188],
    '국어': [90, 40, 80, 40, 15, 80, 55],
    '영어': [85, 35, 75, 60, 20, 100, 65],
    '수학': [100, 50, 70, 70, 10, 95, 45],
    '과학': [95, 55, 80, 75, 35, 85, 40],
    '사회': [85, 25, 75, 80, 10, 80, 35],
    'SW특기': ['Python', 'Java', 'Javascript', '', 'C', 'Python', 'C#']
}

# DataFrame 생성
df = pd.DataFrame(data)
df.index = ['1번', '2번', '3번', '4번', '5번', '6번', '7번']

# 생성된 DataFrame 출력
df.index.name='지원번호'

df
# Out:
#        이름   학교    키  국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197  90   85  100  95  85      Python
# 2번    정대만  북산고  184  40   35   50  55  25        Java
# 3번    송태섭  북산고  168  80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187  40   60   70  75  80
# 5번    강백호  북산고  188  15   20   10  35  10           C
# 6번    황태산  능남고  202  80  100   95  85  80      Python
# 7번    윤대형  능남고  188  55   65   45  40  35          C#

# %% [markdown]
# index 초기화

# %%
df.reset_index()
# Out:
#   지원번호   이름   학교    키  국어   영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197  90   85  100  95  85      Python
# 1   2번  정대만  북산고  184  40   35   50  55  25        Java
# 2   3번  송태섭  북산고  168  80   75   70  80  75  Javascript
# 3   4번  서태웅  북산고  187  40   60   70  75  80
# 4   5번  강백호  북산고  188  15   20   10  35  10           C
# 5   6번  황태산  능남고  202  80  100   95  85  80      Python
# 6   7번  윤대형  능남고  188  55   65   45  40  35          C#

# %%
df.reset_index(drop=True)
# Out:
#     이름   학교    키  국어   영어   수학  과학  사회        SW특기
# 0  채치수  북산고  197  90   85  100  95  85      Python
# 1  정대만  북산고  184  40   35   50  55  25        Java
# 2  송태섭  북산고  168  80   75   70  80  75  Javascript
# 3  서태웅  북산고  187  40   60   70  75  80
# 4  강백호  북산고  188  15   20   10  35  10           C
# 5  황태산  능남고  202  80  100   95  85  80      Python
# 6  윤대형  능남고  188  55   65   45  40  35          C#

# %%
df
# Out:
#        이름   학교    키  국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197  90   85  100  95  85      Python
# 2번    정대만  북산고  184  40   35   50  55  25        Java
# 3번    송태섭  북산고  168  80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187  40   60   70  75  80
# 5번    강백호  북산고  188  15   20   10  35  10           C
# 6번    황태산  능남고  202  80  100   95  85  80      Python
# 7번    윤대형  능남고  188  55   65   45  40  35          C#

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#     이름   학교    키  국어   영어   수학  과학  사회        SW특기
# 0  채치수  북산고  197  90   85  100  95  85      Python
# 1  정대만  북산고  184  40   35   50  55  25        Java
# 2  송태섭  북산고  168  80   75   70  80  75  Javascript
# 3  서태웅  북산고  187  40   60   70  75  80
# 4  강백호  북산고  188  15   20   10  35  10           C
# 5  황태산  능남고  202  80  100   95  85  80      Python
# 6  윤대형  능남고  188  55   65   45  40  35          C#

# %% [markdown]
# Index 설정

# %%
df.set_index('이름')
# Out:
#       학교    키  국어   영어   수학  과학  사회        SW특기
# 이름
# 채치수  북산고  197  90   85  100  95  85      Python
# 정대만  북산고  184  40   35   50  55  25        Java
# 송태섭  북산고  168  80   75   70  80  75  Javascript
# 서태웅  북산고  187  40   60   70  75  80
# 강백호  북산고  188  15   20   10  35  10           C
# 황태산  능남고  202  80  100   95  85  80      Python
# 윤대형  능남고  188  55   65   45  40  35          C#

# %%
df
# Out:
#     이름   학교    키  국어   영어   수학  과학  사회        SW특기
# 0  채치수  북산고  197  90   85  100  95  85      Python
# 1  정대만  북산고  184  40   35   50  55  25        Java
# 2  송태섭  북산고  168  80   75   70  80  75  Javascript
# 3  서태웅  북산고  187  40   60   70  75  80
# 4  강백호  북산고  188  15   20   10  35  10           C
# 5  황태산  능남고  202  80  100   95  85  80      Python
# 6  윤대형  능남고  188  55   65   45  40  35          C#

# %%
df.set_index('이름',inplace=True)
df
# Out:
#       학교    키  국어   영어   수학  과학  사회        SW특기
# 이름
# 채치수  북산고  197  90   85  100  95  85      Python
# 정대만  북산고  184  40   35   50  55  25        Java
# 송태섭  북산고  168  80   75   70  80  75  Javascript
# 서태웅  북산고  187  40   60   70  75  80
# 강백호  북산고  188  15   20   10  35  10           C
# 황태산  능남고  202  80  100   95  85  80      Python
# 윤대형  능남고  188  55   65   45  40  35          C#

# %% [markdown]
# index 정렬

# %%
df.sort_index()
# Out:
#       학교    키  국어   영어   수학  과학  사회        SW특기
# 이름
# 강백호  북산고  188  15   20   10  35  10           C
# 서태웅  북산고  187  40   60   70  75  80
# 송태섭  북산고  168  80   75   70  80  75  Javascript
# 윤대형  능남고  188  55   65   45  40  35          C#
# 정대만  북산고  184  40   35   50  55  25        Java
# 채치수  북산고  197  90   85  100  95  85      Python
# 황태산  능남고  202  80  100   95  85  80      Python

# %%
df.sort_index(ascending=False)
# Out:
#       학교    키  국어   영어   수학  과학  사회        SW특기
# 이름
# 황태산  능남고  202  80  100   95  85  80      Python
# 채치수  북산고  197  90   85  100  95  85      Python
# 정대만  북산고  184  40   35   50  55  25        Java
# 윤대형  능남고  188  55   65   45  40  35          C#
# 송태섭  북산고  168  80   75   70  80  75  Javascript
# 서태웅  북산고  187  40   60   70  75  80
# 강백호  북산고  188  15   20   10  35  10           C
